# %%
import pandas as pd
from local_package.conversion_to_spherical_harmonics import traceless_cartesian_to_spherical

# %%
input_file='data/all_methods_main_dataset.json'
df=pd.read_json(input_file)

# %%
print(df.index)
# Out:
#       molecular_formula                                                 D  \
# 0                    PN                                [0.0, 0.0, 1.1598]
# 1                   HOF               [0.0, -0.6271, 0.42060000000000003]
# 2                 NH2OH                            [-0.0151, 0.0, 0.2747]
# 3                CH3NH2  [-0.5257000000000001, 0.0, -0.11520000000000001]
# 4                 HCOOH   [0.0, -0.12390000000000001, 0.5649000000000001]
# ...                 ...                                               ...
# 15911               PH3                   [0.20040000000000002, 0.0, 0.0]
# 15912                BF                                [0.0, 0.0, -0.393]
# 15913                 H                                   [0.0, 0.0, 0.0]
# 15914               FNO                             [0.0, -0.12, -0.5728]
# 15915            HCONH2               [0.0, -0.32070000000000004, 1.4715]
#
#                                           DDP  \
# ...
